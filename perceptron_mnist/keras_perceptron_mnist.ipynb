# %% [markdown]
# # MNIST with Perceptron using Keras

# %% [markdown]
# ## Setup

# %%
import time
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('./.data/', one_hot=True)
# Out:
# Using TensorFlow backend.
# Extracting ./.data/train-images-idx3-ubyte.gz
# Extracting ./.data/train-labels-idx1-ubyte.gz
# Extracting ./.data/t10k-images-idx3-ubyte.gz
# Extracting ./.data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ## Define network

# %%
model = Sequential()
model.add(Dense(10, input_shape=(784,)))
model.add(Activation('softmax'))

# %% [markdown]
# ## Train

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

# %%
t0 = time.time()
model.fit(mnist.train.images, mnist.train.labels, batch_size=32, nb_epoch=10)
print "training time = {}".format(time.time() - t0)
# Out:
# Epoch 1/10
# 55000/55000 [==============================] - 4s - loss: 0.8152 - acc: 0.8079
# Epoch 2/10
# 55000/55000 [==============================] - 4s - loss: 0.4699 - acc: 0.8779
# Epoch 3/10
# 55000/55000 [==============================] - 4s - loss: 0.4134 - acc: 0.8880
# Epoch 4/10
# 55000/55000 [==============================] - 4s - loss: 0.3853 - acc: 0.8939
# Epoch 5/10
# 55000/55000 [==============================] - 4s - loss: 0.3675 - acc: 0.8986
# Epoch 6/10
# 55000/55000 [==============================] - 4s - loss: 0.3550 - acc: 0.9013
# Epoch 7/10
# 55000/55000 [==============================] - 4s - loss: 0.3454 - acc: 0.9035
# Epoch 8/10
# 55000/55000 [==============================] - 4s - loss: 0.3379 - acc: 0.9055
# Epoch 9/10
# 55000/55000 [==============================] - 4s - loss: 0.3317 - acc: 0.9075
# Epoch 10/10
# 55000/55000 [==============================] - 4s - loss: 0.3266 - acc: 0.9087
# training time = 43.0644209385

# %% [markdown]
# ### Evaluate

# %%
score = model.evaluate(mnist.test.images, mnist.test.labels, verbose=1)
# Out:
#  9984/10000 [============================>.] - ETA: 0s

# %%
print score
# Out:
# [0.30863595905900004, 0.91369999999999996]
