# %% [markdown]
# # MNIST with Perceptron using Keras

# %% [markdown]
# ## Setup

# %%
import time
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('./.data/', one_hot=True)
# Out:
# Using TensorFlow backend.
# Extracting ./.data/train-images-idx3-ubyte.gz
# Extracting ./.data/train-labels-idx1-ubyte.gz
# Extracting ./.data/t10k-images-idx3-ubyte.gz
# Extracting ./.data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ## Define network

# %%
model = Sequential()
model.add(Dense(10, input_shape=(784,)))
model.add(Activation('softmax'))

# %% [markdown]
# ## Train

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

# %%
t0 = time.time()
model.fit(mnist.train.images, mnist.train.labels, batch_size=32, nb_epoch=10)
print "training time = {}".format(time.time() - t0)
# Out:
# Epoch 1/10
# 55000/55000 [==============================] - 4s - loss: 0.8021 - acc: 0.8153
# Epoch 2/10
# 55000/55000 [==============================] - 4s - loss: 0.4680 - acc: 0.8785
# Epoch 3/10
# 55000/55000 [==============================] - 4s - loss: 0.4123 - acc: 0.8899
# Epoch 4/10
# 55000/55000 [==============================] - 4s - loss: 0.3846 - acc: 0.8955
# Epoch 5/10
# 55000/55000 [==============================] - 4s - loss: 0.3671 - acc: 0.8987
# Epoch 6/10
# 55000/55000 [==============================] - 4s - loss: 0.3545 - acc: 0.9020
# Epoch 7/10
# 55000/55000 [==============================] - 4s - loss: 0.3451 - acc: 0.9043
# Epoch 8/10
# 55000/55000 [==============================] - 4s - loss: 0.3376 - acc: 0.9063
# Epoch 9/10
# 55000/55000 [==============================] - 4s - loss: 0.3315 - acc: 0.9078
# Epoch 10/10
# 55000/55000 [==============================] - 4s - loss: 0.3264 - acc: 0.9093
# training time = 43.2336759567

# %% [markdown]
# ### Evaluate

# %%
score = model.evaluate(mnist.test.images, mnist.test.labels, verbose=1)

# %%
print score
# Out:
# [0.30753751057982442, 0.91510000000000002]
